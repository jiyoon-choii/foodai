# %% [markdown]
# ## 단어 빈도수대로

# %%
- 0:100   
['again', 'amazing', 'back', 'bad', 'blue', 'bother',
 'check', 'cheese', 'continue', 'didn', 'don', 'eat', 'egg', 'exactly',
 'expected', 'fast', 'food', 'for', 'from', 'get', 'getting', 'give','got',
 'great','greeted', 'had',   ' section','busy',
 'impressed', 'instead', 'kimchi', 'later', 'less', 'like', 'little', 'looked',
 'looking', 'lunch', 'miso', 'never', 'next', 'order',  'party', 'pay',
   'price', 'quickly', 'radish', 'receive', 'received', 'recommend',
 'remember', 'rice', 'same',  'seated', 'served', 'service', 'sick',
 'side', 'smelled', 'soup', 'stars', 'taking',  'tofu', 'top' 'try',
  'with', 'without', 'highly']

# %%
- 100:200
- 직접 
['spicy','favorably','freshly','spiciness','seasoned','sweet','strong','sweat',
'sort','tasty','sour']
- 간접
['several','big','fan','far','from','expert','but','clean',
 'professional','many','try','excellent','won','disappointed','local',
'small','business','nice','surprise','yummy','good','original','reasonable'
 ,'well','stone','love','too','not','want','never','come','favor',
'delicious','attractive','great','sizzling','veges',
'complaint','popular','early','spot','challenge'
 ,'understandably','slow','worth','wait','obligatory','sides','service',
'meals','cooked','moderately','last','fantastic',
'though','miss','favorite','trip','bunch','korean','check','regret',
'course','regular','selection','supper','way','fair','reminds','awesome','die'
'first','reasonably','priced','reduced'
'enjoy','close','cost','compared','servers','helpful','compare','dined','better',
'few','over','often','best','enjoyed','eating','least','consider','understand',
'closed','made','buffet','value','pricey','recall','tip','included',
'gooood','fresh','use','tripadvisor','rolled'.'goodness','spacious','likely',
'take','one','must','know','used','although','rough','feel','bar','select',
'traditional','typical','chef','desirous','varieties','full','off',
'attentive','meal','star','stars','other','choice','restaurants','care','limited','experience','decent','bland',
'until','added','waiter','bill','super','vegetarian','less','surprisingly',
'regularly','disappoint','standard','merit','however','different',
'polite','flavor','generous','cuisine','optimistic','expensive','similar',
'recommended','appreciate','offered','refused','offer','charming','prices','family',
'ate','tasted','cheap','friends','couldn','allergens','prior','paying','change',
'lowered','minus','disappoints','crave','willing','familiar','enough','general',
'atmosphere','calm','reserved','peaceful','relaxing','classic','pleasant','taste',
 'tasty','wasted','despite','shared','wish','careful','happy','nicely',
'style','cramped','trouble','attention','easily','inside','retaining','expect','respect',
'baby','make','recommendation','lucky','tried','possible','favourite','bed',
'filled','cheaper','worthy','craving','recipe','paid','remember','mistakes',
'online','overwhelming','waitress','kpop','type','main','deep','trying',
'said','alternative','supposed','claypot','matter','dry','reasons','liked',
,'list','app','waitresses','respectful','hard','skills','blonde','negative',
'glad','beaten','fancy','casual', 'suggest','charged','members','satisfying','children',
 'satisfied','waiters','smelling','cook','memories','ever','lower',
 'intimate','loved','quick','photo','level','review','wonderful',
 'should','mind','lovely','filling','perfect','gonna','incredible','affordable',
 'dying','solid','problem','rather','ambience','famous','comparable','positively',
 'suprised','smells','odd','lack','classical','based','reviews','deal','travel',
 'couisine','memory','old','travelling','need','needed','asian',
 'unique','lovers','new','proportion','visit','staff','friendly','hadn','didn','wasn',
'kind','eaten','various','ate','okay','seemed','wont','doesn','sure','water'
'welcoming','originally','terrible','vegetarians','huge','lover','large','honestly'
'sick','defrosted','lot','fix','near','return', 'variations','overpaying','courteous',
'sorry','expecting','splendid','prepared','biggest','cozy','incredibly','nonetheless',
'reason','tricky','avarage','soon','hidden''gladly','quiet', 'increased','kinds',
,'smaller','luck','overall','birthday','celebration','winter','extreme','pictures',
,'improved','favouring','light','frequently','dry','anymore','romantic','date',
'hungry','miss','gentle','easiest','expecting','unbeatable','lazy','warmth',
'will','pink',]

 - 음식
['bulgogi','bbq','bimbimbap','beef','chigae','jampon','seafood'
 ,'noodles','onion','cake','ribs','chicken','red','lettuce','wraps','daikon',
'pickled','fish','cucumbers','carrots','soup','vegetable','cucumber','kimbop','pancake',
'pajeon','beats','meat','dumplings','salmon','bean','pork','staffsmayo','eggs','nuts',
,'gimchi','tuna','gimgap','potato','bokeum','bap','beer','hotteok','ice',
 'cream', 'lettuces','udong',,'sauce','salad','crowd','bibbabi]

# %%
-200:300
- 직접
['spices','raw','braised','healthy','abundance',
'spicyness','seasoned','fermented',]
- 간접
['comfy', 'rarely','comfortable','following','excelent','picky',
'native','hit','more','awkward','craved','successful','spoiled','impressive','special',
'tradition','followed','plentiful','problems','accessible','regrets','money','impossible',
,'differance','ingridents','resonable','speciality','positive','average',
'expanded','wouldn','wonder','variety','freshness','testify','pics',
 'problematic','bearable','waited','demanding','international','albeit',
'detail','patient','dissatisfied','cold','elsewhere','efficient','unsure',
'valuable','original','poor','ingredients','beginner','foreigners','budget',
'language','interesting','acquainted','weren','common','troubles','likes','dont',
 'beautiful','impeccable','informal','compensates','white','haven','uncomfortable',
 'cheapest','thanks','unexpected','excited','signature','veggies','appreciated',
 'solid','bits','green','diet','name','attempt','natural','stick','services',
 'recommed','disadvantage','fabulous','supernice','beware','occasions','named',
 'called',
 'reccomend','dissapointed','choice','fault','star','stars','contains','possibly','considerable',
'surprised','understandable','avoids','pleased','happier','amazingly','savored',
'smile','exquisite','croweded','strangers','welcomed','cosy','bite','vege','vegetaratian',
'helpfull','locals','koreans','wholesome','raised','seems','easy','luckily',
'disappointingly', 'mains','felt','tips','revisit','delay','annoyed',
'seem','restuarant','loves','korea','kindest','wasnt','fav','smiling','recommendable',
'helped','wonderfully','artistically','pleasurable','spent','bistro','fulfill','combo',
'heated','point','maxi','roll','gimmick','potion','size','overly','introduced','costs',
'huge','highlights','dining','homemade','please']
- 음식
[ 'ramen','soups','bit', 'haemul','dubu','jjigae','bibimbap','goulash','desire',
'wishing','wrong','enjoyable','ginger','tea','wine','kkanpunggi','vegetables','balls',
'bap','potato','carrot','cuisine','platter','squid','pudding','kimbap','crispy',
'soft','onion','chilli','powder','sauces','jaeyook','vegan','plum','lemon','gimbap',
'rolls','bogogi','bibimbab','jigae','friend','banchan']

# %%
-300:400
- 직접 
['yammi','sugar','oily','flavourful','flavoursome','spice',
 'row',  'yommy', 'flavour','crisp','flavoured','texture',
 'boiled','crispy','watery','chilled','salty',

- 간접 
['difficult','stone','basically','cleaning','prawnlot','tastes','burnt',
 'drank','afterwards','refreshing','drink','simple','hearty',
 'dream','expectations','precooked','forgot','yuck','yum','flavours',
 ,'rate',
'explained', 'combinations','waiting','exceeded', 'speechless',
'warm','confused','tiny','slices','bizarre',,'even','formerly',
'known','basic','focus','added','ambiance','honesty','includes',
'starters','starter','consisted','eaters','forgettable','yet',
 'essential','provided','orders','brilliant','rare','age','enhance',
 'honestly','understanding','wanted','incorrectly','byob',
 'quirky','deprawnlight','together','tuck','right','lol',
 'allergic','treat','safely','recprawneptive','problemos','revitalised',
 'max','extblewremely','grubby','blewlick','banquet','gatherings','complaints',
 'misleading','agree','patchy','sadly','start','kim','particular',
 'effort','makes','boiling','takes','add','avoid','contrast',
 'westernised','pan','spots','plan','adventurous','over',
 'accompany','nasty','effects','warming','larger','quantities',
 'alcohol','types','son','bohemian','unless','accompanied',
 'absolutely','mixed','veg','wild','stunned','relaxed','hype',
 'lacking','generally','tasteless','cultures','cuisines',
 'diverse','mixture','cuisine','posh','pay','pitched',
 'nothing','chopsticks','advise','revisit','questionable',
 'hashtag','amazeballs','opinion','smiles','look','beautifully',
 'luxurious','finely','balanced','welcome','adores',
 'accommodating','pots','minor','soul','dearly','missedblew
 'veggie','information','sampled','bought','asked',
 'dirty','descent','actually','concept','ordeal','stop',
 'fails','impress','bonus','struggled','proper','motherland',
 'unimposing','chefs','wary','concerned','any','hotness',
 'scale','green','finish','unpretentious','guess','esp',
 'recommends','missing','valued','physically','bothered',
 'sufficient','satisfactory','minimum','bills','summer',
 'guests','create','giving','comment','honest','recommending',
 'delivery','useful','pointed','layered','control','happily',
 'feeling','mostly','bargain','improvements','joint','kids',
 'normal','shabby','importantly','specials','gather','fairly',
 'weird', 'laidback','quality','tired','hurry','looks'
 
]
-음식 
['pokum','curry','paste','honey','beers','panko','rib','orange',
 'changed','salads','prawns','pickles','bipimbap','sesame','kimchee',
'soup','bibibap','soba','radishes','soya','noodle','pancakes',
'broth','galbi','mandu','booze','bim','gyoza','broths','bab',
'tempura','wrap','square','wasabi','mushrioms','icecream',
'teas','bibimap','vodka','burger','stew','citron','bibimpap']
