# %% [markdown]
# # 전처리할 데이터프레임 로드

# %%
import re

# %%
import pandas as pd
df = pd.read_csv('/home/team/바탕화면/파이널프로젝트/data/tripadvisor_df.csv')

# %%
# len("'been', 'here', 'times'")
# Out:
# 23

# %% [markdown]
# ## stopword 지정

# %%
stop = [
    'about','also', 'and','because','box','dish','dishes','etc','front','cashier',
   'his', 'husband', 'immediately','just','menu', 'minutes','others','our','relay',
    'some', 'that', 'the', 'their','them', 'then', 'this', 'very', 
   'walked', 'was', 'were','what', 'when', 'women','gotta',  
   'how', 'ordered','pieces','seat'
    'been','here', 'times', 'and', 'this','the','are',
 'there','options','had','have','you','find','pretty','choose',
'parking ','were','plenty','pot','they','serve','free','low','supporting',
'day','cuz','eat','box','today','chance','something','else','really','short',
'wife','plate','always','second','time','very','came','out','thier','authentic',
'bowl','table','still','bottom','sunny','all','some','your','kept','almost',
'definitly','recently','stopped','arrived','packed','plus','including','restaraunt',
'cellophane','slivers','went','night','staying','home','wide','now','offerings',
'other','just','range','once','car','drive','miles','foods','dish','visiting','visited',
 'become','someone','decorated','country','chose'
'along','ordering','would','stay','land','people','half','long','spent','could',
'dozen','mixes','each','yeas','locations','found','especially','significantly','plae',
'two','blocks','away','trained','places','quite','can','min','years','started','lived',
'countries','myself','versed','twice','week','owned','own','currently','has','sushi',
'order','correctly','around','couple','sooo','through','sister',
'rest','being','three','ordered','yakimondo','say','portions','groups',
'due','neighbor','most','pass','only','looking','word','mouth','building'
'outside','interior','where','opted','guest','another','presentation',
'show','work','done','mizo','while','did','sample',
'till','open','seats','across','street','which','certainly','proclaim',
'somewhat','amount','navigating','hole','wall','gets','anything','how',
'into','probably','put','anyway','yesterday','whole','its','speak',
'corner','ethnic','everything','coming','kitchen','things',
'properly','black','below','frozen','let','down','definitely',
'what','randomly','during','our','managed','past','location','exterior',
'alone','single','piece','gimchi''told','whether','ended','takeaway','aspects',
'dropped','accumulated','mother','law','completely','aged','finding','round','fooled',
'explain','those','who','tourist','itself','themed','decorations','seems',
 'delicately','ranges','udon','persons','sets','basem','portions','ent','turning',
 'reservation','literally','meters','tram','station','plain','view','look',
 'fact','stairs','helping','after','step','realize','setting','pleasing',
 'decor','motives','modern','lines','entered','certify','personal','touch','noticed',
 'high','chair','weekend','per','noticing','accommodation','book','advance',
 'evening','upon','arrival','considered','ourselves','tables','predominantly',
 'boyfriend','clear','joked','asking','prompt','center','longer',
 'morning','sight','seeing','gave','mispronounced',
 'thoroughly','trio','cokes','walking','dad','took','mums','house','might','comfort',
 'mean','isn','either','reminded','higher','because','prime','hours','search','gem',
 'required','minute','ride','see','neighborhood','part','flat','city','accept',
 'carry','imagine','ready','customer','accommodated','requests','daughter',
 'owner','patient','split','non','pesto','beginning','choices',
 'end','saved','tongues','every','pay','sized','portion','background','playing',
 'person', 'mension','sayd','does','locate','environment',
 'true','stated','she','layers','realized',
 'redo','both','leaves','slightly','broth','standards','serving',
 'presented','characteristics','personally','her','meant','immediately',
 'much','chat','woman','card','path','means','dress','before','line',
 'since','hair','real','speaks','centrally','located','englyakiish',
 'issue','owners','afternoon','four','making','meet',
 'enter','definetly','semi','gone','particularly','available',
 'walk','downside','crowns','rooms','feels','totally','knew', 'guess',
 'advisable','ahead','apartment','advisor','heart','warming','door',
 'notch','area','somewhere','boxes','overshadowed', 'by','frequent','eater','reference',
 'material','unassuming','arrive','cash','earth','abroad','exquisite',
 'conditioning','ventilation','mindblowing','mention','hold','sitting',
 'air','ground','customers','days','doing','road','definately',
 'give','everyday','cloths','hanger','cute',
'degree','less',
'czk','simply','allowed','importantly','mom', 'uber','ride',
'our','group','comes','aunt','owns','grew','hands','school','absolute','having','seen',
'steps','partner','tray','searching','lie','finish','centre',
'brought','everyone','older','usually','evenings','booking','confirm',
'authenticity','planned','stuff','centrum','going',
'shop','mix','already','month','terms',
'delve','below','wise','attentiveness','empty','occassion','revealed','amplified',
'nervous','seated','anyone','hello','mins','happening','third','somehow',
'youngsters','jacket','live','nearby','substantially',
'jap','identify','blamed','provides',
'study','think','eum','ppong','talking','tap','exactly','remembers',
'placed','address','speaking','dull','humble','surroundings','cuz',
'hospital','suchi','further','relatively','skeptical','chocked','par',
'letdown','tad','why','prohibitively','washed','downplay',
'extensive','thing','massive','rush','touched','job','growing','reservations',
'keep','offering','reading','often','nonsense','number','etnic','extra','assurance',
'decor','thus','maybe','yourself','gentl','hearty','eman','five','perhaps',
'amounts','suspicions','confirmed','sight','crystals','struggle','taxi',
'man','knows','occasion','able','booked','dined','temperature','host','checked',
'four,','correct','fat','stole','town','plus','move','stops',
'prepared','played','pop','spice','help','personnel','girlfriend','genuinly','version',
'doubt','occasional','tailored','given','aware','moving','cooking',
'key','zizkov','staircase','map','eventually','passion','othet','let',
'plates','arugula','minced','manager','fifteen','complicated',
'ours','stayed','hotel','relation','usual','appears','may','tonight',
'europe','fluent','encountered','truly', 'accident','randomly','living','obsessed',
'goes','cross','moved','became','whatever','responsive','regard','descriptive',
 'listings','maintaining','wooing','evr','tourism','greeted','months','traveling',
 'happened','world','recipes','cure','weakness','ower','afford','fuss',
 'forward','else','office','item','crowns','via','returned','serves',
 'design','discover','shout','deserves','category','share','show','staple','whenever','could','bottle','because','unusual','under','manage','place',
'goal', 'genuinely','caring','opend','manger','early',
'student','mediocre','piping','fridge','just','mentioned',
'server','said','stored','putting','available','presented',
'slightly','cafe','than','time','think','thin','covered',
'actual','usable','plastic','bicycle','joke','believe',
 'size','dinner','considering','such','bring','drinks',
 'dishes','name','establishment','complimentary','returning',
 'weekends','everybody','set','thinking','heard','things',
 'tenfold','brim','sharing','working','accommodate','numbered',
 'wrote','overshadowed','instructions','someone','both','paint',
 'throughout','brighten','couples','families','forgive','chee',
 'songs','array','implies','milieu','impromptu','items','tucked',
 'themselves','policy','guidance','iceberg','glass','bemoaning',
 'stumbled','approach','distinctly','population','guy','attended',
 'bristol','head','thee','him','born','sometimes','yeah',
 'bang','supply','cos','shovel','literally','branding',
 'levs','accompaniments','ones','left','faces','promising',
 'functional','edge','custom','corkage','ago','recent','decorate',
 'rushed','gripe','finished','blew','catering','hear','rushing',
 'tell','glasses','cleared','arriving','ages','situation',
 'saw','shame','between','grub','nosh','whirl',
 'situated','smart','diners','herself','guide','square',
 'shredded','tailor','training','team','chase',
 'realised','mins','process','repeatedly','management',
 'arrangement','sitting','sat','simplicity','everywhere',
 'centre','exam','period','revision','teriyaki','told',
 'her','earthenware','bottom','taken','definite','gone',
 'previously','cafes','lots','total','extras',
 'wash','lunchtime','nights','popped','resturant',
 'thought','decide','offers','sell','ask','greeting'
]

# %%
# 체크

# df = df[df['res_name'] == 'Korea House']
# list(df['review'])

# %%
# df['review'].unique()

# %%
# type(df['review'])

# %%
# df['review'] = df['review'].astype(str)

# %% [markdown]
# ### stopword 제거(1차)

# %%
import re
sub_list = list()
for i in stop :
#     print(i)
    p = re.compile( i )
#     print(0)
    for idx in range(len(df['review'])) :
        if type(df['review'][idx]) == str :
            df['review'][idx]= p.sub('',df['review'][idx])
            
        else :
            pass
    print('끝')
# #         print(1)
        
# #         print(2)
# Out:
# /home/team/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝

# %% [markdown]
# - 저장

# %%
df.to_csv('/home/team/바탕화면/파이널프로젝트/data/stop1.csv')

# %% [markdown]
# ## stopword 제거(2차)

# %%
df2 = pd.read_csv('/home/team/바탕화면/파이널프로젝트/data/stop1.csv')
df2.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                    cls_attr     res_name  \
# 0           0          1462  ui_bubble_rating bubble_50  Korea House
# 1           1          1463  ui_bubble_rating bubble_50  Korea House
# 2           2          1464  ui_bubble_rating bubble_50  Korea House
# 3           3          1465  ui_bubble_rating bubble_40  Korea House
# 4           4          1466  ui_bubble_rating bubble_50  Korea House
#
#   food_name                           user_name  \
# 0    아시아 요리                AppleTech\n헤더슨빌, 테네시
# 1    아시아 요리                 NickyD202\n내슈빌, 테네시
# 2    아시아 요리             RCSColumbus\n콜럼버스, 오하이오
# 3    아시아 요리               Btravelfood\n내슈빌, 테네시
# 4    아시아 요리  cmcwhirter33\nNashville, Tennessee
#
#                                          rev_title  \
# 0  Fun and Authentic Experience with Great Service
# 1                          Get the seafood pancake
# 2                             The Real Deal Korean
# 3                                          Banchan
# 4                                   Excellent food
#
#                                               review  \
# 0  We’d never  Korean   I’d been wanting to try t...
# 1  I   unsure of   of    appeal to me at Korea Ho...
# 2  Absolutely delicious ic Korean food d in a no-...
# 3  The banchan or side es  y    I love  t aurant....
# 4  My eleven year old twins beg to get bibop on s...
#
#                               food
# 0  ['kimchijjigae', 'samgyeopsal']
# 1  ['kimchijjigae', 'samgyeopsal']
# 2  ['kimchijjigae', 'samgyeopsal']
# 3  ['kimchijjigae', 'samgyeopsal']
# 4  ['kimchijjigae', 'samgyeopsal']

# %%
stop2 = [
    '.',',','a','to','it','is','was','the','we','!','place','so','that','be',
    '(','one','us','also','this','when','an','ing','me','-','they','even',
    'lunch','than','...',"''",'you','got',':','take','ever','seoul','2',"''",'and',
    'he','all','having','think','am','3','near','?','english','waiter','said','waitress',
    '&','decided','ate','his',':','5','our','thing','$','victoria','sch','absolutely',
    '4','set','10','told','after','why','definitely','thought','soon',
    'hotel','floor','music','extremely','comes','had','brought','bring',"''",'lady',
    'etc','building','maybe','saw','she','offer','able','6','business','number','waitress',
    'swiches','won','items','room','beween','sit','getting','tell','--','option','sing',
    '20,','use','30','finish','sat','only','..','ago','7','their','offered','waiters',
    'finid','some','chef','bite','15','quiet','shop','reason','forward','glass',
    'provided','yes','yet','host','self','elevator','both','turned','%','stuff',
    'idea','read','him','shopping','then','fly','reading','ones','note','space',
    'oh','met','store','8','taken','2nd','goes','clossed','staffs','months','life',
    'while','leaving','100','bottle','month', 'its','came','market','eye','believe',
    'considering','station','straingt','cut','stockholm','head','total','visited',
    'suggest','behind','tap','establishm','cuts','"','rush','hit','taking','office',
    'ordered','owner''received','litery','man','needs','guy','buy','dine','surprisingly',
    'manager','living','whenever','five','talking','since','offers','provide',
    'watch','wear','12','previous','cafe','talk','checking','sun','crew','wow','"',
    'been','guys','noon','forget','colleagues','list','probably','moved','50',
    'obviously','break','stumbled','#','suggested','stuffed','returned','directly',
    'did','checked','ladies','exit','finishamong','girls','branch','version','takes','cup',
    'giving','worry','shot','bars','unl''imited','pub','terms','portions','face',
    'hospitality','accompanied','agree','chose'
    '40s','testing','bible','calculator','2,700won','grabbed','22.30','anticipation',
    'hahahaha','3,000won','consumer','2800','considerate','wonders','5000','insult',
    'consume','hung','drawn','parked''room','board','related','booth','shoulder','ow','tolerance',
    'uses','understaffed','flooring','ceramic','controlled','thingy','recesses','arms',
    'struggling','630pm','dates','afterwards','licking','tremously','live''automaticy',
    'mark','cigtte','katusa','painted','open','military','economical','reding',
    'pet','exchange','immensely''16''front','do','gs',
    'of','my',')','staff','or','meal','saw''over','bit','come',"'",'cooked','waitress',
    'asked','choice','feel',';','selection','dining','meals','return','temple',
    'husb','bar','start','felt','makes','cooking','trying','old','restaurant',
    'leave','close','presed','rself','20','underst','menus','fectly','princess',
    'icularly','dance','paulo','orial','orwise','oh','buddhist','condims',
    'deal','selves','watching','compely','closed','heard','hope',
    'spoon','get','at',"'re",'dine-in','august','aurant','intensely','참기름','고기구이',
    "'s",'aurants','visit',"'ve",'ething','way','er','right',"'m",'especiy','son',
    "'d","'ll",'tasting','actuy','usuy','eone','highly','sign','elf','hs','stard',
    'toger','ve','attion','diners','counter','pick','gas','addition','icular','very',
    'answer','numerous','among','satur','shd','tastes','feeling','shoes','ers','holborn',
    'by','moves','/','supposed','establishm','button','hed','sony','drop',
    '9',
]

# %%
import re
sub_list = list()
try :
    for i in stop :
    #     print(i)
        p = re.compile( i )
    #     print(0)
        for idx in range(len(df2['review'])) :
            if type(df2['review'][idx]) == str :
                df2['review'][idx]= p.sub('',df2['review'][idx])

            else :
                pass
        print('끝')
except :
    print("에러")
# #         print(1)
# Out:
# /home/team/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 에러

# %% [markdown]
# - 저장

# %%
df2.to_csv('/home/team/바탕화면/파이널프로젝트/data/stop2.csv')

# %% [markdown]
# ## stopword 제거 (3차)

# %%
df3 = pd.read_csv('/home/team/바탕화면/파이널프로젝트/data/stop2.csv')
# list(stop2['review'][:100]

# %%
df3['review'][:100]
# Out:
# 0                  NaN
# 1         \n\n\n\n\n\n
# 2                  NaN
# 3                  NaN
# 4                  NaN
#             ...
# 95    \n\n\n\n\n\n\n\n
# 96                 NaN
# 97                 NaN
# 98    \n\n\n\n\n\n\n\n
# 99                 NaN
# Name: review, Length: 100, dtype: object

# %%
stop3_1 = [
    '.',',','to','is','it','the','!','aurant','so','at','be',')','one',"'s",'get',
    'been','me','they','even','come','visit','lunch','bit','you','make','take','reason',
    '’','aurants','very','2','``','feel','and','he','3',"'re","''",'am','all','?','res',
    '&','near',';','$','our','when','4','10','definitely','makes','felt','also','floor',
    'extremely','meals','close','leave','music',"'",'what','trying','business', 'lady',
   'just','6','room','that', 'she','offer','building','some','chose','restaurant','sing',
    'getting','elf','20','--','their','won','30','..','15','swiches','offered','only',
    '7','was','quiet','having', 'idea','self','both','then','note','oh','closed',
    'provided','read','cut','store','pick','elevator','while','came','visited','its',
    'leaving','station','met','sun','”','received','have','market','since','absolutely',
    'litery','eye','behind','questions','establishm','cuts','provide','“','buy',
    'wow', 'obviously','hang','talk','spoke','checking','wear'
]

# %%
import re
sub_list = list()
for i in stop3_1 :
#     print(i)
    p = re.compile( i )
#     print(0)
    for idx in range(len(df3['review'])) :
        if type(df3['review'][idx]) == str :
            df3['review'][idx]= p.sub('',df3['review'][idx])
            
        else :
            pass
    print('끝')
# Out:
# /home/team/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# 끝
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-24-0aa20e2b8d21> in <module>
#       3 for i in stop3_1 :
#       4 #     print(i)
# ----> 5     p = re.compile( i )
#       6 #     print(0)
#       7     for idx in range(len(df3['review'])) :
#
# ~/anaconda3/lib/python3.7/re.py in compile(pattern, flags)
#     232 def compile(pattern, flags=0):
#     233     "Compile a regular expression pattern, returning a Pattern object."
# --> 234     return _compile(pattern, flags)
#     235
#     236 def purge():
#
# ~/anaconda3/lib/python3.7/re.py in _compile(pattern, flags)
#     284     if not sre_compile.isstring(pattern):
#     285         raise TypeError("first argument must be string or compiled pattern")
# --> 286     p = sre_compile.compile(pattern, flags)
#     287     if not (flags & DEBUG):
#     288         if len(_cache) >= _MAXCACHE:
#
# ~/anaconda3/lib/python3.7/sre_compile.py in compile(p, flags)
#     762     if isstring(p):
#     763         pattern = p
# --> 764         p = sre_parse.parse(p, flags)
#     765     else:
#     766         pattern = None
#
# ~/anaconda3/lib/python3.7/sre_parse.py in parse(str, flags, pattern)
#     936     if source.next is not None:
#     937         assert source.next == ")"
# --> 938         raise source.error("unbalanced parenthesis")
#     939
#     940     if flags & SRE_FLAG_DEBUG:
#
# error: unbalanced parenthesis at position 0

# %% [markdown]
# - 저장

# %%
df.to_csv('/home/team/바탕화면/파이널프로젝트/data/stop2.csv')
