# %%
# 20200513_밤 트립어드바이저 파일 합치기 에 전체 코드 나와있다

# %%
import pandas as pd
df = pd.read_csv('./data/df_tmp.csv')

# %%
res_name_unique = df['res_name'].unique()

# %%
len(df)

# %%
# for i in trip[24794:49340+1] :
#     j in res_name_unique_list : 
#     if trip[i] == res_name_unique_list[j] :
#         food_name = []
#         for k in range(len(food_name)) :
#             trip['food'][i] = food_name[k]

# %%
# 식당 이름 : 메뉴 딕셔너리 형태로 입력하기 
# all = {} 
# for i in range(len(res_name_unique_list[281:])) :
#     print(res_name_unique_list[281:][i])
#     x = input()
#     all[res_name_unique_list[281:][i]] = x

# %% [markdown]
# ## 텍스트 파일 읽기
# 1) 여러줄,한줄 다 있는 거

# %%
# def read_txt(filename,sep='') :
#     str = ''
    
#     file = open(filename,'r',encoding='utf-8')
    
#     str = file.readlines()
    
#     for i in range(0,len(str)) :
#         str[i] = str[i].strip().split(sep)
#     return(str)

#     file.close()
    
# all_add = read_txt('./data/value.txt',',')

# %%
# res_food_add=dict()
# for i in range(int(len(all_add)/2)) :
# #     print(i*2,i*2+1)
#     print(all_add[i*2],all_add[i*2+1])
    
#     res_food_add[all_add[i*2][0]] = all_add[i*2+1]
    
# res_food_add

# %% [markdown]
# 2) 한줄 한줄 있는거

# %%
# with open('./data/res_food2.txt', 'r', encoding='utf-8') as food2 :
#     food_list2 = food2.readlines()

# %%
# tmp=[]
# for i in range(len(food_list2)) :
#     k = food_list2[i]
# #     print(type(k.rstrip()))
#     str_k = k.rstrip()
#     print(str_k)
#     break

# %%
# 음식 영어표기명 텍스트파일 불러오기 

# f = open('food_name_in_eng.txt', 'r')
# data = f.read()
# print(data)
# f.close()

# %%
# good = list()
# with open('./data/food_in_eng_dictionary.txt','r',encoding='utf-8') as file :
#     for text in file :
#         print(text.strip('\n'))
#         good = text.strip('\n')

# %% [markdown]
# ## 피클 파일 처리

# %% [markdown]
# - 로드

# %%
# with open('./data/res_menu1.pickle', 'rb') as f:
#     res_menu1_dic = pickle.load(f)

# %% [markdown]
# - 저장

# %%
# import text

# with open('res_name_add.pickle', 'wb') as f:
#     text.write(res_food_add, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## 딕셔너리 합치기

# %%
# def Merge(dict1, dict3, dict4) :
#     return{**dict1, **dict3, **dict4}

# res_menu_all = Merge(res_menu1_dic, res_menu3_dic, res_menu4_dic)

# %%
### 바꾸기

# %%
# for i in res_menu_all :
# #     print(i)
#     k = res_menu_all[i] 
# #     print(k)
#     for j in range(len(k)):
# #         print(j)
#         for x in food_name_dict.keys() :
#             if (res_menu_all[i][j] in x) or (x in res_menu_all[i][j]) :
#                 res_menu_all[i][j] = food_name_dict[x]

# %% [markdown]
# # 음식 종류 라벨 추가

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 트립어드바이저 크롤링 파일 합치기

# %%
df = pd.read_csv('./data/df_tmp.csv')

# %%
len(trip) #49340
# Out:
# 49340

# %%
trip[24794:49340+1]
res_name_unique_list = list(trip['res_name'].unique())
# len(res_name_unique_list) = 560
# res_name_all 의 row 수와 같은지 확인
# Out:
# 560

# %%
import pickle

# %%
# 음식사전 불러오기 
file=open("./data/food_name_dic.pickle","rb")
food_name_dic=pickle.load(file)
food_name_dic
# https://weejw.tistory.com/31
# Out:
# {'갈비구이': 'galbigui',
#  '갈치구이': 'galchigui',
#  '고등어구이': 'godeungeogui',
#  '곱창구이': 'gopchanggui',
#  '닭갈비': 'dakgalbi',
#  '더덕구이': 'deodeokgui',
#  '떡갈비': 'tteokgalbi',
#  '불고기': 'bulgogi',
#  '삼겹살': 'samgyeopsal',
#  '장어구이': 'jangeogui',
#  '조개구이': 'jogaegui',
#  '조기구이': 'jogigui',
#  '황태구이': 'hwangtaegui',
#  '훈제오리': 'hunjeori',
#  '계란국': 'gyelangug',
#  '떡국_만두국': 'tteokguk_mandutguk',
#  '무국': 'muguk',
#  '미역국': 'miyeokguk',
#  '북엇국': 'bugeotguk',
#  '시래기국': 'siraegiguk',
#  '육개장': 'yukgaejang',
#  '콩나물국': 'kongnamulguk',
#  '과메기': 'gwamegi',
#  '양념치킨': 'yangnyeomchicken',
#  '젓갈': 'jeotgal',
#  '콩자반': 'kongjaban',
#  '편육': 'pyeonyuk',
#  '피자': 'pizza',
#  '후라이드치킨': 'friedchicken',
#  '갓김치': 'gatkimchi',
#  '깍두기': 'kkakdugi',
#  '나박김치': 'nabakkimchi',
#  '무생채': 'musaengchae',
#  '배추김치': 'baechukimchi',
#  '백김치': 'baekkimchi',
#  '부추김치': 'buchukimchi',
#  '열무김치': 'yeolmukimchi',
#  '오이소박이': 'oisobagi',
#  '총각김치': 'chonggakkimchi',
#  '파김치': 'pakimchi',
#  '가지볶음': 'gajibokkeum',
# ...

# %%
# 식당별 메뉴 들고오기 
f = open("./data/res_menu_edit_all.pickle","rb") 
file2 = pickle.load(f) 
file2
# Out:
# {'치즈웨이브': ['pizza'],
#  'Cho Sun OK Restaurant': ['galbigui',
#   'baechukimchi',
#   'kongnamulmuchim',
#   'godeungeogui',
#   'kimchijjigae',
#   'bulgogi',
#   'maeuntang',
#   'dongtaejjigae'],
#  'Sura Korean Cuisine': ['tteokbokki',
#   'pajeon',
#   'jeyukbokkeum',
#   'mandu',
#   'japchae',
#   'bulgogi',
#   'yukgaejang',
#   'oisobagi'],
#  'Jin Korean BBQ': ['galbigui', 'samgyeopsal'],
#  '원당감자탕 명동1호점': ['gamjatang',
#   'mandu',
#   'gyeranmari',
#   'baechukimchi',
#   'kkakdugi',
#   'samgyetang',
#   'bulgogi',
#   'pajeon',
#   'bibimbap'],
#  '연타발 강남역점': ['galbigui', 'baechukimchi', 'dotorimuk'],
#  'Smoki Moto': ['jangjorim',
#   'sujebi',
#   'eomukbokkeum',
#   'kkakdugi',
#   'baechukimchi',
#   'gochujangjinmichaebokkeum',
#   'gamjatang'],
#  'Benu': ['saeutwigim', 'galbigui'],
#  'Ong Gie': ['galbigui', 'gamjajorim', 'kimchijjigae', 'bibimbap'],
#  'Angry Tofu': ['bibimbap', 'dubujorim', 'kongnamulmuchim'],
#  "Hahn's Kitchen": ['bulgogi',
# ...

# %%
# 처리 후 ('김치' 등 한국말은 수동으로 뺐음) 피클로 저장 
import pickle

file=open("./data/res_menu_all_final.pickle","wb")
pickle.dump(res_menu_all,file)
file.close()


# 출처: https://weejw.tistory.com/31 [위지원의 삽질 블로그]

# %%
# 수정된 식당별 메뉴
f=open('./data/res_menu_all_final.pickle',"rb") 
res_menu_all=pickle.load(f) 
res_menu_all
# Out:
# {'치즈웨이브': ['pizza'],
#  'Cho Sun OK Restaurant': ['galbigui',
#   'baechukimchi',
#   'kongnamulmuchim',
#   'godeungeogui',
#   'kimchijjigae',
#   'bulgogi',
#   'maeuntang',
#   'dongtaejjigae'],
#  'Sura Korean Cuisine': ['tteokbokki',
#   'pajeon',
#   'jeyukbokkeum',
#   'mandu',
#   'japchae',
#   'bulgogi',
#   'yukgaejang',
#   'oisobagi'],
#  'Jin Korean BBQ': ['galbigui', 'samgyeopsal'],
#  '원당감자탕 명동1호점': ['gamjatang',
#   'mandu',
#   'gyeranmari',
#   'baechukimchi',
#   'kkakdugi',
#   'samgyetang',
#   'bulgogi',
#   'pajeon',
#   'bibimbap'],
#  '연타발 강남역점': ['galbigui', 'baechukimchi', 'dotorimuk'],
#  'Smoki Moto': ['jangjorim',
#   'sujebi',
#   'eomukbokkeum',
#   'kkakdugi',
#   'baechukimchi',
#   'gochujangjinmichaebokkeum',
#   'gamjatang'],
#  'Benu': ['saeutwigim', 'galbigui'],
#  'Ong Gie': ['galbigui', 'gamjajorim', 'kimchijjigae', 'bibimbap'],
#  'Angry Tofu': ['bibimbap', 'dubujorim', 'kongnamulmuchim'],
#  "Hahn's Kitchen": ['bulgogi',
# ...

# %% [markdown]
# ## 이상 데이터는 None값으로 처리

# %%
import pickle

dic=res_menu
file=open("fileName","wb")
pickle.dump(dic,file)
file.close()

# %%
file1=open("./data/res_menu_edit_all.pickle","rb")
res_menu=pickle.load(file1)
res_menu
# https://weejw.tistory.com/31
# Out:
# {'치즈웨이브': ['pizza'],
#  'Cho Sun OK Restaurant': ['galbigui',
#   'baechukimchi',
#   'kongnamulmuchim',
#   'godeungeogui',
#   'kimchijjigae',
#   'bulgogi',
#   'maeuntang',
#   'dongtaejjigae'],
#  'Sura Korean Cuisine': ['tteokbokki',
#   'pajeon',
#   'jeyukbokkeum',
#   'mandu',
#   'japchae',
#   'bulgogi',
#   'yukgaejang',
#   'oisobagi'],
#  'Jin Korean BBQ': ['galbigui', 'samgyeopsal'],
#  '원당감자탕 명동1호점': ['gamjatang',
#   'mandu',
#   'gyeranmari',
#   'baechukimchi',
#   'kkakdugi',
#   'samgyetang',
#   'bulgogi',
#   'pajeon',
#   'bibimbap'],
#  '연타발 강남역점': ['galbigui', 'baechukimchi', 'dotorimuk'],
#  'Smoki Moto': ['jangjorim',
#   'sujebi',
#   'eomukbokkeum',
#   'kkakdugi',
#   'baechukimchi',
#   'gochujangjinmichaebokkeum',
#   'gamjatang'],
#  'Benu': ['saeutwigim', 'galbigui'],
#  'Ong Gie': ['galbigui', 'gamjajorim', 'kimchijjigae', 'bibimbap'],
#  'Angry Tofu': ['bibimbap', 'dubujorim', 'kongnamulmuchim'],
#  "Hahn's Kitchen": ['bulgogi',
# ...

# %%
# 불량 데이터 넌으로 변경
dum = [["''"],["'"],[" "],[""],['coffee']]
for i,j in res_menu_all.items():
#     print(i,j)
    if j in dum:
        print(j)
        res_menu_all[i]=[None]

#         print(i)
# Out:
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ['coffee']
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ['coffee']
# ["''"]
# ['coffee']
# ['coffee']
# ["''"]
# ["''"]
# ["''"]
# ['coffee']
# ["''"]
# ["''"]
# ['coffee']
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ["''"]
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['coffee']
# ['']
# ['coffee']
# ['']
# ['']

# %%
res_menu_all
# Out:
# {'치즈웨이브': ['pizza'],
#  'Cho Sun OK Restaurant': ['galbigui',
#   'baechukimchi',
#   'kongnamulmuchim',
#   'godeungeogui',
#   'kimchijjigae',
#   'bulgogi',
#   'maeuntang',
#   'dongtaejjigae'],
#  'Sura Korean Cuisine': ['tteokbokki',
#   'pajeon',
#   'jeyukbokkeum',
#   'mandu',
#   'japchae',
#   'bulgogi',
#   'yukgaejang',
#   'oisobagi'],
#  'Jin Korean BBQ': ['galbigui', 'samgyeopsal'],
#  '원당감자탕 명동1호점': ['gamjatang',
#   'mandu',
#   'gyeranmari',
#   'baechukimchi',
#   'kkakdugi',
#   'samgyetang',
#   'bulgogi',
#   'pajeon',
#   'bibimbap'],
#  '연타발 강남역점': ['galbigui', 'baechukimchi', 'dotorimuk'],
#  'Smoki Moto': ['jangjorim',
#   'sujebi',
#   'eomukbokkeum',
#   'kkakdugi',
#   'baechukimchi',
#   'gochujangjinmichaebokkeum',
#   'gamjatang'],
#  'Benu': ['saeutwigim', 'galbigui'],
#  'Ong Gie': ['galbigui', 'gamjajorim', 'kimchijjigae', 'bibimbap'],
#  'Angry Tofu': ['bibimbap', 'dubujorim', 'kongnamulmuchim'],
#  "Hahn's Kitchen": ['bulgogi',
# ...

# %%
# None 값으로 바뀌었는지 데이터프레임으로 보기 
# ain = pd.DataFrame.from_dict(res_menu_all, orient='index')

# %% [markdown]
# ## df['food']의 값과 와 res_menu_all의 식당명을 비교하여 일치하는 식당을 메뉴로 바꾸기

# %%
df = pd.read_csv('./data/df_tmp.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                    cls_attr     res_name food_name  \
# 0        1462  ui_bubble_rating bubble_50  Korea House    아시아 요리
# 1        1463  ui_bubble_rating bubble_50  Korea House    아시아 요리
# 2        1464  ui_bubble_rating bubble_50  Korea House    아시아 요리
# 3        1465  ui_bubble_rating bubble_40  Korea House    아시아 요리
# 4        1466  ui_bubble_rating bubble_50  Korea House    아시아 요리
#
#                             user_name  \
# 0                AppleTech\n헤더슨빌, 테네시
# 1                 NickyD202\n내슈빌, 테네시
# 2             RCSColumbus\n콜럼버스, 오하이오
# 3               Btravelfood\n내슈빌, 테네시
# 4  cmcwhirter33\nNashville, Tennessee
#
#                                          rev_title  \
# 0  Fun and Authentic Experience with Great Service
# 1                          Get the seafood pancake
# 2                             The Real Deal Korean
# 3                                          Banchan
# 4                                   Excellent food
#
# ...

# %%
# for x,y in res_menu_all.items() :
# #     print(x)
#     for i in range(len(df['food'])) :
# #         print(i)
#         if x == df['food'][i] : 
#             df['food'][i] = res_menu_all[x]
#         else :
#             continue

# %%
for i in range(len(df['food'])) :
#     print(i)
    for key,value in res_menu_all.items() :
#         print(key)
        if key == df['food'][i] :
#                 print(df['food'][0])
#                 type(res_menu_all[0][1])   
            df['food'][i] = res_menu_all[key]
#             df['food'].replace(df['food'][i],res_menu_all[key])
        else : 
            continue
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i in range(len(df['food'])) :
    if df['food'][i] == 'Korea House' :
        df['food'][i] = res_menu_all['Korea house']
    else :
        continue
# Out:
# C:\Users\admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
type(df['food'])
# Out:
# pandas.core.series.Series

# %%
df.head()
# Out:
#    Unnamed: 0                    cls_attr     res_name food_name  \
# 0        1462  ui_bubble_rating bubble_50  Korea House    아시아 요리
# 1        1463  ui_bubble_rating bubble_50  Korea House    아시아 요리
# 2        1464  ui_bubble_rating bubble_50  Korea House    아시아 요리
# 3        1465  ui_bubble_rating bubble_40  Korea House    아시아 요리
# 4        1466  ui_bubble_rating bubble_50  Korea House    아시아 요리
#
#                             user_name  \
# 0                AppleTech\n헤더슨빌, 테네시
# 1                 NickyD202\n내슈빌, 테네시
# 2             RCSColumbus\n콜럼버스, 오하이오
# 3               Btravelfood\n내슈빌, 테네시
# 4  cmcwhirter33\nNashville, Tennessee
#
#                                          rev_title  \
# 0  Fun and Authentic Experience with Great Service
# 1                          Get the seafood pancake
# 2                             The Real Deal Korean
# 3                                          Banchan
# 4                                   Excellent food
#
# ...

# %%
df['food'].value_counts()

# %%
df.to_csv('./data/tripadvisor_df.csv',index=False)
